# %%
import plotly.express as px
import pandas as pd
import numpy as np
import scipy.stats
import math
import warnings
warnings.filterwarnings("ignore")

# %%
df_gr=pd.read_excel('/Users/hannahkamen/Downloads/temp_changes.xlsx')

# %%
df_gr['Extreme Cold Day Change']=df_gr['fextcold']
df_gr['Extreme Hot Day Change']=df_gr['fexthot_28']

# %%
fig = px.choropleth(df_gr,
                    locations='abbrev', 
                    locationmode="USA-states", 
                    scope="usa",
                    color='Extreme Hot Day Change',
                    color_continuous_scale="reds", 
                    
                    )
fig.show()
# Out:
# <div>                            <div id="eefbd12c-50e4-45fc-969b-f7dc6be8de3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eefbd12c-50e4-45fc-969b-f7dc6be8de3e")) {                    Plotly.newPlot(                        "eefbd12c-50e4-45fc-969b-f7dc6be8de3e",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"abbrev=%{location}<br>Extreme Hot Day Change=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AZ","AR","CA","CO","CT","DE","FL","GA","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","WA","WI"],"name":"","z":[94.90328216552734,59.56521224975586,41.82064819335938,71.3361282348632
# ...
