# %%
import pandas as pd
import numpy as np
import scipy.stats
import math
import warnings
warnings.filterwarnings("ignore")
dpath='/Users/hannahkamen/Downloads'

# %%
climate_new=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/climate.dta')

# %%
climate_old=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/second_stage_dataset_cl.dta')

# %%
tmp0=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/projection_data_age2_0.dta')
#############merge state lookup onto both projections 
sl=pd.read_excel('/Users/hannahkamen/Downloads/statelookup2.xlsx')
tmp0=tmp0.merge(sl,on='statefip',how='inner')
tmp=tmp0.groupby(['state'],as_index=False).agg({'fexthot_28':max,'fextcold':max,'share':sum,'chosen':sum})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/w1/12ls607j77q1jk587t2n5t2r0000gn/T/ipykernel_21600/272311713.py in <module>
# ----> 1 tmp0=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/projection_data_age2_0.dta')
#       2 #############merge state lookup onto both projections
#       3 sl=pd.read_excel('/Users/hannahkamen/Downloads/statelookup2.xlsx')
#       4 tmp0=tmp0.merge(sl,on='statefip',how='inner')
#       5 tmp=tmp0.groupby(['state'],as_index=False).agg({'fexthot_28':max,'fextcold':max,'share':sum,'chosen':sum})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/stata.py in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    1939 ) -> DataFrame | StataReader:
#    1940
# -> 1941     reader = StataReader(
#    1942         filepath_or_buffer,
#    1943         convert_dates=convert_dates,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/stata.py in __init__(self, path_or_buf, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, compression, storage_options)
#    1089
#    1090         self._native_byteorder = _set_endianness(sys.byteorder)
# -> 1091         with get_handle(
#    1092             path_or_buf,
#    1093             "rb",
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/projection_data_age2_0.dta'

# %%
list(climate_old)
# Out:
# ['index',
#  'wa_fbin158',
#  'wa_fbin159',
#  'wa_fbin160',
#  'wa_fbin161',
#  'wa_fbin162',
#  'wa_fbin163',
#  'wa_fbin164',
#  'wa_fbin165',
#  'wa_fbin166',
#  'wa_fbin167',
#  'wa_fbin168',
#  'wa_fbin169',
#  'wa_fbin170',
#  'wa_fbin171',
#  'wa_fbin172',
#  'wa_fbin173',
#  'wa_fbin174',
#  'wa_fbin175',
#  'wa_fbin176',
#  'wa_fbin177',
#  'wa_fbin178',
#  'wa_fbin179',
#  'wa_fbin180',
#  'wa_fbin181',
#  'wa_fbin182',
#  'wa_fbin183',
#  'wa_fbin184',
#  'wa_fbin185',
#  'wa_fbin186',
#  'wa_fbin187',
#  'wa_fbin188',
#  'wa_fbin189',
#  'wa_fbin190',
#  'wa_fbin191',
#  'wa_fbin192',
#  'wa_fbin193',
#  'wa_fbin194',
#  'wa_fbin195',
#  'wa_fbin196',
#  'wa_fbin197',
#  'wa_fbin198',
#  'wa_fbin199',
#  'wa_fbin200',
#  'wa_fbin201',
#  'wa_fbin202',
#  'wa_fbin203',
#  'wa_fbin204',
#  'wa_fbin205',
#  'wa_fbin206',
#  'wa_fbin207',
#  'wa_fbin208',
#  'wa_fbin209',
#  'wa_fbin210',
#  'wa_fbin211',
#  'wa_fbin212',
#  'wa_fbin213',
#  'wa_fbin214',
#  'wa_fbin215',
#  'wa_fbin216',
#  'wa_fbin217',
#  'wa_fbin218',
#  'wa_fbin219',
#  'wa_fbin220',
#  'wa_fbin221',
#  'wa_fbin222',
#  'wa_fbin1',
#  'wa_fbin2',
#  'wa_fbin3',
#  'wa_fbin4',
#  'wa_fbin5',
#  'wa_fbin6',
#  'wa_fbin7',
#  'wa_fbin8',
#  'wa_fbin9',
#  'wa_fbin10',
#  'wa_fbin11',
#  'wa_fbin12',
#  'wa_fbin13',
#  'wa_fbin14',
#  'wa_fbin15',
#  'wa_fbin16',
#  'wa_fbin17',
#  'wa_fbin18',
#  'wa_fbin19',
#  'wa_fbin20',
#  'wa_fbin21',
#  'wa_fbin22',
#  'wa_fbin23',
#  'wa_fbin24',
#  'wa_fbin25',
#  'wa_fbin26',
#  'wa_fbin27',
#  'wa_fbin28',
#  'wa_fbin29',
#  'wa_fbin30',
#  'wa_fbin31',
#  'wa_fbin32',
#  'wa_fbin33',
#  'wa_fbin34',
#  'wa_fbin35',
#  'wa_fbin36',
#  'wa_fbin37',
#  'wa_fbin38',
#  'wa_fbin39',
#  'wa_fbin40',
#  'wa_fbin41',
#  'wa_fbin42',
#  'wa_fbin43',
#  'wa_fbin44',
#  'wa_fbin45',
#  'wa_fbin46',
#  'wa_fbin47',
#  'wa_fbin48',
#  'wa_fbin49',
#  'wa_fbin50',
#  'wa_fbin51',
#  'wa_fbin52',
#  'wa_fbin53',
#  'wa_fbin54',
#  'wa_fbin55',
#  'wa_fbin56',
#  'wa_fbin57',
#  'wa_fbin58',
#  'wa_fbin59',
#  'wa_fbin60',
#  'wa_fbin61',
#  'wa_fbin62',
#  'wa_fbin63',
#  'wa_fbin64',
#  'wa_fbin65',
#  'wa_fbin66',
#  'wa_fbin67',
#  'wa_fbin68',
#  'wa_fbin69',
#  'wa_fbin70',
#  'wa_fbin71',
#  'wa_fbin72',
#  'wa_fbin73',
#  'wa_fbin74',
#  'wa_fbin75',
#  'wa_fbin76',
#  'wa_fbin77',
#  'wa_fbin78',
#  'wa_fbin79',
#  'wa_fbin80',
#  'wa_fbin81',
#  'wa_fbin82',
#  'wa_fbin83',
#  'wa_fbin84',
#  'wa_fbin85',
#  'wa_fbin86',
#  'wa_fbin87',
#  'wa_fbin88',
#  'wa_fbin89',
#  'wa_fbin90',
#  'wa_fbin91',
#  'wa_fbin92',
#  'wa_fbin93',
#  'wa_fbin94',
#  'wa_fbin95',
#  'wa_fbin96',
#  'wa_fbin97',
#  'wa_fbin98',
#  'wa_fbin99',
#  'wa_fbin100',
#  'wa_fbin101',
#  'msa',
#  'regionfe',
#  'statefip',
#  'lnrho',
#  'metarea',
#  'hot',
#  'cold',
#  'avgtemp',
#  'precip',
#  'dewpt',
#  'relhum',
#  'sun',
#  'lnsea',
#  'lnsea2',
#  'lnlake',
#  'lnlake2',
#  'lnslope',
#  'lnden',
#  'lnhsgrad',
#  'lncoll',
#  'lngrad',
#  'lnage',
#  'lnhisp',
#  'lnblack',
#  'lnprec',
#  'lndewpt',
#  'lnrelhum',
#  'lnsun',
#  'lnavgtemp',
#  'lnpop',
#  'lnmanu',
#  'lngvt',
#  'lnpropt',
#  'lnincome',
#  'lnwhite',
#  'lncrime']

# %%
tmp_old=climate_old[[x for x in climate_old.columns if x in hot_list]]
tmp_old['total_hot_delta']=tmp_old.sum(axis=1)
tmp_old['total_hot_delta'].min()

# %%
tmp_old['total_hot_delta'].describe()

# %%
tmp['total_hot_delta'].describe()

# %%
hot_list=[]
for i in np.arange(158,223,1):
    hot_list.append('wa_fbin%s'%i)

# %%
tmp=climate_new[[x for x in climate_new.columns if x in hot_list]]
#tmp.to_excel('%s/climate_new_test.xlsx'%dpath)

# %%
tmp['total_hot_delta']=tmp.sum(axis=1)

# %%
tmp

# %%
for i in np.arrange(158,223,1):
    tmp=climate_new[[x for x in climatenew.columns if ]]
    climate_new['future_hot']=climate_new['climate_new']

egen fexthot_28 = rowtotal(wa_fbin158-wa_fbin222)

# %%
list(climate_new)

# %%
# tmp0_gr=tmp0.groupby(['msa','statefip'],as_index=False).agg({'id':sum})
# bmk0_gr=bmk0.groupby(['msa'],as_index=False).agg({'id':sum})
# msaid_state_lookup=tmp0_gr[['msa','statefip']].merge(bmk0_gr[['msa']],on='msa').groupby(['msa','statefip'],as_index=False).sum()
# msaid_state_lookup.to_excel('/Users/hannahkamen/Downloads/msaid_state_lookup.xlsx')

# %%
###get state age and education estimates

state_split=pd.read_excel('/Users/hannahkamen/Downloads/state_pop_educ_shares.xlsx')
state_age_shares=pd.read_excel('/Users/hannahkamen/Downloads/state_age_shares.xlsx')
msaid_state_lookup=pd.read_excel('/Users/hannahkamen/Downloads/msaid_state_lookup.xlsx')

state_split=state_split[['skl_2','skl_3','skl_4','skl_5','skl_6','skl_7','unskl_2','unskl_3','unskl_4','unskl_5','unskl_6','unskl_7','state','state_pop']]

master=pd.DataFrame()
for a in [2]:
    for i in [0,1]:       
        try:
            del tmp0
            del bmk0
        except:
            print("first loop")
        
        #(1) read in projection data, and benchmark population shares

        tmp0=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/projection_data_age2_%s.dta'%i)
        bmk0=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/projection_data_age2_%s_test.dta'%i)

        #############merge state lookup onto both projections 
        sl=pd.read_excel('/Users/hannahkamen/Downloads/statelookup2.xlsx')
        tmp0=tmp0.merge(sl,on='statefip',how='inner')
        bmk0=bmk0.merge(msaid_state_lookup,on='msa').merge(sl,on='statefip',how='inner')

        #(2) merge pop share estimates from each group

        ########group benchmark and projected by state, sum shares and chosen to get pct change
        tmp=tmp0.groupby(['state'],as_index=False).agg({'fexthot_28':max,'fextcold':max,'share':sum,'chosen':sum})
        bmk=bmk0.groupby(['state'],as_index=False).agg({'share':sum,'chosen':sum})
        bmk=bmk.rename(columns={'share':'benchmark_pop'})
        bmk=bmk[['state','benchmark_pop']]

        ########merge grouped projections with benchmark to get pct change
        tmp=tmp.merge(bmk,on='state')
        tmp['pct_change']=(tmp['share']-tmp['benchmark_pop'])/tmp['benchmark_pop']

        ########merge pct changes onto population by age

        tmp=tmp.merge(state_age_shares,on='state',how='inner')
        tmp['age_id']= a
        tmp['educ_id']=i
        
        ########SET AGE GROUP TWO TO 100 PERCENT OF POPULATION FOR NOW
        #tmp['contribution_to_total_change']=tmp['pct_change']*tmp['%s'%a]
        tmp['contribution_to_total_change']=tmp['pct_change']*1
        
        ######## append all age and skill datasets
        master=master.append(tmp)


#(3) translate age group to total population pct change

master_gr=master.groupby(['state','educ_id'],as_index=False).agg({'contribution_to_total_change':sum})

# %%
#(4) export to gams format
master_gr['educ_id']=master_gr['educ_id'].astype(str).str.replace('0','unskl').str.replace('1','skl')
master_gr=master_gr.merge(sl,on='state',how='inner')
master_gr=master_gr.rename(columns={'abbrev':'','educ_id':'sk','contribution_to_total_change':'skill_shr'})
master_gr=master_gr[['','sk','skill_shr']]
master_gr.to_csv('/Users/hannahkamen/Downloads/le0_shock_0.csv',index=False)

# %%
master_gr.to_csv('/Users/hannahkamen/Downloads/le0_shock_0.csv',index=False)

# %%
master_gr.to_excel('/Users/hannahkamen/Downloads/age_2_backup.xlsx')

# %%
master_gr['state']

# %%
master_gr[master_gr['state']=='indiana']

# %%
master_gr['contribution_to_total_change']=np.where(((master_gr['state']=='illinois') & (master_gr['educ_id']==0)),-0.578497,master_gr['contribution_to_total_change'])
master_gr['contribution_to_total_change']=np.where(((master_gr['state']=='illinois') & (master_gr['educ_id']==1)),-0.598063,master_gr['contribution_to_total_change'])

# %%
master_gr['contribution_to_total_change'].min()

# %%
tmp['pct_change2']=(tmp['share']-tmp['chosen'])/tmp['chosen']

# %%
abs(tmp['pct_change2']).mean()

# %%
abs(tmp['pct_change']).mean()

# %%
master_gr

# %%
test=tmp0[tmp0['state']=='illinois']

# %%
list(test)

# %%
test_lm=test[[
 'lnage',
 'lnhisp',
 'lnblack',
 'lnprec',
 'lndewpt',
 'lnrelhum',
 'lnsun',
 'lnavgtemp',
 'lnpop',
 'lnmanu',
 'lngvt',
 'lnpropt',
 'lnincome',
 'lnwhite',
 'lncrime']]

# %%
test_lm['clizone_r']

# %%
test_lm['fextcold']

# %%
list(test)

# %%
master_gr['contribution_to_total_change'].min()

# %% [markdown]
# ##### (9) map out migration flows

# %%
#get sum of shares in all other states for people who chose states 1-44
#get ids that live in state s currentlly
master_map=pd.DataFrame()
for s in df_m['state'].unique():
    living_now=[]
    df_lm=df_m[(df_m['state']==s) & (df_m['chosen']==1)]
    ####list of ids currently living in state s
    living_now.append(list(df_lm['id'].unique())[0])
    ###limit dataframe to the ids of people living in state s
    tmp=df_m[df_m['id'].isin(living_now)]
    ####now groupby shares across all states
    tmp2=tmp.groupby(['state'],as_index=False).agg({'share':sum})
    ###tag origin state
    tmp2['living_flag']=s
    master_map=master_map.append(tmp2)
    
######merge with state populaiton
master_map0=master_map.merge(state_split,left_on='living_flag',right_on='state',how='inner')
master_map0=master_map0.rename(columns={'state_x':'moving_to'})

####get estimates for number of people leaving / going to
master_map0['arrive_moving_to']=master_map0['unskl_2']*master_map0['state_pop']

####merge in the msa codes

master_map0_lm=master_map0[master_map0['living_flag']=='texas']

###export texas test

master_map0_lm.to_csv('/Users/hannahkamen/Downloads/texas_out_unskl2.csv')

# %%
map_dta=pd.read_csv('/Users/hannahkamen/Downloads/census_texas.csv')

# %%
map_dta_lm=map_dta[map_dta['GEOID2'].str.contains(',')]

map_dta_lm['state']=map_dta_lm['GEOID2'].apply(lambda x: x.split(',')[1])
map_dta_lm['state']=map_dta_lm['GEOID2'].apply(lambda x: x.split(',')[1])

# %%
map_dta_lm

# %%
map_dta['state']

# %%
list(map_dta['GEOID2'])

# %%
master_map0.head()

# %%
##test to see what is happening with temperature

# %%
# df_tmp[df_tmp['state']=='washington']

# %%
master_map.sort_values(by='share',ascending=False).head(100)

# %%
master_map.head()

# %%
df_lm

# %%
master_map.head()

# %%
df_test_gre

# %%
df_tmp

# %%
df_test_gre

# %%
# df_m[(df_m['id']==3)& (df_m['state']=='california')][['msa','bpl','chosen','d_s','d_r1','d_r2','statefip','state']]

# %%
df_test_gre['diff']=abs(df_test_gre['share']-df_test_gre['chosen'])

# %%
df_test_gre['diff'].describe()

# %%
# df_tmp=df_m.groupby(['msa'],as_index=False).agg({'fexthot_28':sum,'fextcold':sum,'state':max,'hot':sum,'cold':sum})

# %%
# df_m[['msa','state','hot','cold','fexthot_28','fextcold']].head()

# %%
len(df[(df['id']==4100)]['msa'].unique())

# %%
list()

# %%
logit_ready[logit_ready['chosen']==1]['d_s'].describe()

# %%
df_lm=df[['msa','chosen','share']]

# %%
df[df['chosen']==1]['share'].describe()

# %% [markdown]
# #### Import total population and process percent changes for Windc counterfactual

# %%
#orig=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/dta/dta/acs5yr_0610_clr.dta')

#orig.groupby(['ageid'],as_index=False)

# %%
###get shares by college graduates#impo
#educ_shares.to_csv('/Users/hannahkamen/Downloads/le0_shr2.csv',index=False)
# df['pct_col']=np.exp(df['lncoll'])
# df['pct_nc']=1-np.exp(df['lncoll'])
# df['coll_pop']=np.exp(df['lnpop'])*df['pct_col']
# df['population']=np.exp(df['lnpop'])

# df_tot=df.groupby(['statefip'],as_index=False).agg({'population':sum,'coll_pop':sum,'share':sum,'chosen':sum})
# df_tot['state_coll_shr']=df_tot['coll_pop']/df_tot['population']
# df_tot['pct_change']=(df_tot['share']-df_tot['chosen'])/df_tot['chosen']

# %%
df[df['share'].isnull()]

# %%
df

# %%
list(df)

# %%
df_st=df.groupby('statefip',as_index=False).agg({'share':sum,'population':sum,'chosen':sum,'id':'count'})
df_st['chosen'].sum()

# %%
list(df)

# %%
len(df['id'].unique())

# %%
df_st.head()

# %%
len(df_st['id'].unique())

# %%
44*265

# %%
df[df['id']==62973.0]

# %%
len(df)

# %%
df_st.head()

# %%
len(df['statefip'].unique())

# %%
df.groupby('id',as_index=False).agg({'share':sum})['share'].unique()

# %%
df['msa'].unique()

# %%
len(list(df['msa'].unique()))

# %%
df.head()

# %%
data.head()

# %%
st_lkup=data.groupby(['statefip','str_statefip'],as_index=False).sum()[['statefip','str_statefip']]

# %%
list(data)

# %%
data['str_statefip'].unique()

# %%
list(data)

# %%
st_lkup

# %%
data.head()

# %%
len(data)

# %%
list(data)

# %%
len(logit)

# %%
list(logit)

# %%
logit.head()

# %%
q

# %%
logit.head()

# %%
q.head()

# %%
for i in np.arange(2,8,1):
    print(i)

# %%
for i in np.arange(2,8,1):
    df=pd.read_stata('/Users/hannahkamen/Downloads/population-migration-master/estimation/1_main_specification/acs5yr0610/results/temp/2nd_stage_avg_age%s.dta'%i)

# %%
df

# %%
secondndstage2.head()

# %%
secondndstage3.head()

# %%
logit['_b_d_r1'].unique()

# %%
logit['d_s'].unique()

# %%
len(cols)

# %%
cols=[x for x in logit.columns if "_b" in x]

# %%
for x in [x for x in logit.columns if "_b" in x]:
    
    print(logit[x].unique())

# %%
logit['d_s']
